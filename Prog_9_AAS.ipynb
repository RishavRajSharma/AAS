# %% [markdown]
# <a href="https://colab.research.google.com/github/RishavRajSharma/AAS/blob/main/Prog_9_AAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# User input
choice = input("Enter '1' for manual input or '2' for random RGB: ")

if choice == '1':
    R = int(input("Enter R value: "))
    G = int(input("Enter G value: "))
    B = int(input("Enter B value: "))
else:
    #  Random input
    R = random.randint(0, 255)
    G = random.randint(0, 255)
    B = random.randint(0, 255)

# Grayscale conversion
gray = int(0.3 * R + 0.59 * G + 0.11 * B)

# Output
print("R, G, B:", R, G, B)
print("Grayscale Value:", gray)
# Out:
# Enter '1' for manual input or '2' for random RGB: 1
# Enter R value: 10
# Enter G value: 8
# Enter B value: 8
# R, G, B: 10 8 8
# Grayscale Value: 8
