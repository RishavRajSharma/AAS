# %% [markdown]
# <a href="https://colab.research.google.com/github/RishavRajSharma/AAS/blob/main/Prog_2_AAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import urllib.request

dataset_url = "https://github.com/IntelRealSense/librealsense"
print("Using Dataset Source:", dataset_url)


depth_values = np.array([0.8, 0.6, 0.4, 1.2, 0.3])

print("\nDepth Sensor Readings (meters):")
print(depth_values)

velocity = 1  # Robot moving initially

for distance in depth_values:
    if distance < 0.5:
        velocity = 0
        print("\nObstacle detected at", distance, "meters")
        break

if velocity == 0:
    print("\nOutput: Robot Halted")
    print("Industry: Amazon Fulfillment Robots")
else:
    print("\nOutput: Path Clear - Robot Moving")
# Out:
# Using Dataset Source: https://github.com/IntelRealSense/librealsense
#
# Depth Sensor Readings (meters):
# [0.8 0.6 0.4 1.2 0.3]
#
# Obstacle detected at 0.4 meters
#
# Output: Robot Halted
# Industry: Amazon Fulfillment Robots
